# %%
import pandas as pd

# %%
df = pd.read_csv("final title collection details.csv")

# %%
df.head(139)
# Out:
#                                             Questions     Checkbox  \
# 0                                           Questions     Checkbox
# 1                                           Questions     Checkbox
# 2                                           Questions     Checkbox
# 3     64 PROJECTS FOR EVERY DATA SCIENCE PROFESSIONAL      Correct
# 4                    ENTREPENEURS WHO KNOW HOWTO CODE  Not Correct
# 5       TOP 1O PEOPLE YOU MUST FOLLOW INTHEFIELD OFAI  Not Correct
# 6    HIGH DEMIND SKILLS RIGHTNOW,Not Correct,HIGH ...          NaN
# 7                            Artificial intelligence.          NaN
# 8                                   Sales leadership.          NaN
# 9                                           Analysis.          NaN
# 10                                       Translation.          NaN
# 11                            Mobile app development.          NaN
# 12                                 People management.          NaN
# 13                                 Video production."          NaN
# 14   10 WAYS TO BECOME MENTALLY STRONGER,Correct, ...          NaN
# 15                             Embrace adversity. ...          NaN
# 16                            Exercise your mind. ...          NaN
# 17                            Challenge yourself. ...          NaN
# 18                            Respond positively. ...          NaN
# 19                                    Be mindful. ...          NaN
# 20                     Don't be defeated by fear. ...          NaN
# 21                            Be aware of self-talk."          NaN
# 22              8 SUCCESS STRATEGIES FOR USING IN2021      Correct
# 23   WEEKEND ROUTINE OF SUCCESSFUL PEOPLE,Correct,...          NaN
# 24         They spend time with their loved ones. ...          NaN
# 25             They strategize on the week ahead. ...          NaN
# 26        They make time for what energizes them. ...          NaN
# 27                      They take care of chores. ...          NaN
# 28            They set aside alone time and reflect."          NaN
# 29   SIX STEPS OF GETTIIG RICH,Not Correct,SIX STE...          NaN
# 30  Determine exactly what you intend to give in r...          NaN
# 31  Establish a definite date when you intend to p...          NaN
# 32   BESTDECISIONSTO MAKE IN YOUR 2OS,Not Correct,...          NaN
# 33                       Start an emergency fund. ...          NaN
# 34                              Tackle your debt. ...          NaN
# 35                              Learn new skills. ...          NaN
# 36                           Save for retirement. ...          NaN
# 37                     Don't be afraid to invest. ...          NaN
# 38                           Cut the financial cord."          NaN
# 39   MONEY MAKING 6AOBBIES ITRADING,Not Correct,MO...          NaN
# 40                           Take Online Surveys. ...          NaN
# 41                                   Photography. ...          NaN
# 42                                       Writing. ...          NaN
# 43                                Graphic Design. ...          NaN
# 44                Creating and/or Editing Videos. ...          NaN
# 45                                     Carpentry. ...          NaN
# 46                              Sports – Refereeing."          NaN
# 47                       HOW D0 MOST PEOPLE GET RICH?      Correct
# 48                                          Questions     Checkbox
# 49                                          Questions     Checkbox
#
#                                  Corrected_questions  Answer
# 0                                Corrected_questions  Answer
# 1                                Corrected_questions  Answer
# 2                                Corrected_questions  Answer
# 3    64 PROJECTS FOR EVERY DATA SCIENCE PROFESSIONAL     NaN
# 4                 ENTREPRENEURS WHO KNOW HOW TO CODE     NaN
# 5       TOP 1O PEOPLE YOU MUST FOLLOW IN FIELD OF AI     NaN
# 6                                                NaN     NaN
# 7                                                NaN     NaN
# 8                                                NaN     NaN
# 9                                                NaN     NaN
# 10                                               NaN     NaN
# 11                                               NaN     NaN
# 12                                               NaN     NaN
# 13                                               NaN     NaN
# 14                                               NaN     NaN
# 15                                               NaN     NaN
# 16                                               NaN     NaN
# 17                                               NaN     NaN
# 18                                               NaN     NaN
# 19                                               NaN     NaN
# 20                                               NaN     NaN
# 21                                               NaN     NaN
# 22             8 SUCCESS STRATEGIES FOR USING IN2021     NaN
# 23                                               NaN     NaN
# 24                                               NaN     NaN
# 25                                               NaN     NaN
# 26                                               NaN     NaN
# 27                                               NaN     NaN
# 28                                               NaN     NaN
# 29                                               NaN     NaN
# 30                                               NaN     NaN
# 31                                               NaN     NaN
# 32                                               NaN     NaN
# 33                                               NaN     NaN
# 34                                               NaN     NaN
# 35                                               NaN     NaN
# 36                                               NaN     NaN
# 37                                               NaN     NaN
# 38                                               NaN     NaN
# 39                                               NaN     NaN
# 40                                               NaN     NaN
# 41                                               NaN     NaN
# 42                                               NaN     NaN
# 43                                               NaN     NaN
# 44                                               NaN     NaN
# 45                                               NaN     NaN
# 46                                               NaN     NaN
# 47                      HOW D0 MOST PEOPLE GET RICH?     NaN
# 48                               Corrected_questions  Answer
# 49                               Corrected_questions  Answer

# %%
df["Answer"]
# Out:
# 0      Answer
# 1      Answer
# 2      Answer
# 3         NaN
# 4         NaN
#         ...
# 133       NaN
# 134       NaN
# 135       NaN
# 136       NaN
# 137       NaN
# Name: Answer, Length: 138, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
df.reset_index()
# Out:
#    index  Answer
# 0      0  Answer

# %%
df
# Out:
# 0    Answer
# Name: Answer, dtype: object
